# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from ross import model, helpers

# %% [markdown]
# ## Simple test on 2D data, for easy visualization.

# %%
plt.rcParams["figure.figsize"] = (5,5)

arr = datasets.make_blobs(n_samples=1000, n_features=2, centers=3, cluster_std=1.2, random_state=800)[0]
noise = np.array([np.random.uniform(low=min(arr[:,0]), high=max(arr[:,0]), size=15),
                  np.random.uniform(low=min(arr[:,1]), high=max(arr[:,1]), size=15)]).T
arr = np.vstack([arr, noise])
plt.scatter(arr[:,0], arr[:,1], cmap='Dark2')

# %%
df = pd.DataFrame(arr)
df['labels'] = model.fit_predict(np.array(df))

plt.scatter(df[0], df[1], c=df['labels'], cmap='Accent')
# Out:
# 100%|██████████| 1015/1015 [00:00<00:00, 4578.79it/s]

# %%
df = pd.DataFrame(arr)
df['labels'] = model.fit_predict(arr, binary_flag=True)

plt.scatter(df[0], df[1], c=df['labels'], cmap='Accent')
# Out:
# 100%|██████████| 1015/1015 [00:00<00:00, 4588.93it/s]
