# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

os.chdir('..')
from src import ross

# %% [markdown]
# ## Simple test on 2D data, for easy visualization.

# %%
plt.rcParams["figure.figsize"] = (10,10)

 
plt.scatter(arr[:,0], arr[:,1], cmap='Dark2')

# %%
df = pd.DataFrame(arr)
df['labels'] = ross.fit_predict(arr)

plt.scatter(df[0], df[1], c=df['labels'], cmap='Accent')
# Out:
# 100%|██████████| 1015/1015 [00:00<00:00, 3892.68it/s]

# %%
df = pd.DataFrame(arr)
df['labels'] = ross.fit_predict(arr, binary_flag=True)

plt.scatter(df[0], df[1], c=df['labels'], cmap='Accent')
# Out:
# 100%|██████████| 1015/1015 [00:00<00:00, 3685.05it/s]
